# %% [markdown]
# # **Instructions**:
#
# ### 1 - Open your game that you want to perform detections
# ### 2 - In the game window, get the name of it's title bar
# ### 3 - Update the variable "window_name" with the game title bar name
# ### 4 - Run all cells to start detecting objects using your trained model

# %%
import numpy as np
import win32gui, win32ui, win32con
from PIL import Image
from time import sleep
import cv2 as cv
import os
import random

# %%
class WindowCapture:
    w = 0
    h = 0
    hwnd = None

    def __init__(self, window_name):
        self.hwnd = win32gui.FindWindow(None, window_name)
        if not self.hwnd:
            raise Exception('Window not found: {}'.format(window_name))

        window_rect = win32gui.GetWindowRect(self.hwnd)
        self.w = window_rect[2] - window_rect[0]
        self.h = window_rect[3] - window_rect[1]

        border_pixels = 8
        titlebar_pixels = 30
        self.w = self.w - (border_pixels * 2)
        self.h = self.h - titlebar_pixels - border_pixels
        self.cropped_x = border_pixels
        self.cropped_y = titlebar_pixels

    def get_screenshot(self):
        wDC = win32gui.GetWindowDC(self.hwnd)
        dcObj = win32ui.CreateDCFromHandle(wDC)
        cDC = dcObj.CreateCompatibleDC()
        dataBitMap = win32ui.CreateBitmap()
        dataBitMap.CreateCompatibleBitmap(dcObj, self.w, self.h)
        cDC.SelectObject(dataBitMap)
        cDC.BitBlt((0, 0), (self.w, self.h), dcObj, (self.cropped_x, self.cropped_y), win32con.SRCCOPY)

        signedIntsArray = dataBitMap.GetBitmapBits(True)
        img = np.fromstring(signedIntsArray, dtype='uint8')
        img.shape = (self.h, self.w, 4)

        dcObj.DeleteDC()
        cDC.DeleteDC()
        win32gui.ReleaseDC(self.hwnd, wDC)
        win32gui.DeleteObject(dataBitMap.GetHandle())

        img = img[...,:3]
        img = np.ascontiguousarray(img) 
            
        return img

    def generate_image_dataset(self):
        if not os.path.exists("images"):
            os.mkdir("images")
        while(True):
            img = self.get_screenshot()
            im = Image.fromarray(img[..., [2, 1, 0]])
            im.save(f"./images/img_{len(os.listdir('images'))}.jpeg")
            sleep(1)
    
    def get_window_size(self):
        return (self.w, self.h)

# %%
class ImageProcessor:
    W = 0
    H = 0
    net = None
    ln = None
    classes = {}
    colors = []

    def __init__(self, img_size, cfg_file, weights_file):
        np.random.seed(42)
        self.net = cv.dnn.readNetFromDarknet(cfg_file, weights_file)
        self.net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
        self.ln = self.net.getLayerNames()
        self.ln = [self.ln[i-1] for i in self.net.getUnconnectedOutLayers()]
        self.W = img_size[0]
        self.H = img_size[1]
        
        with open('yolov4-tiny/obj.names', 'r') as file:
            lines = file.readlines()
        for i, line in enumerate(lines):
            self.classes[i] = line.strip()
        
        # If you plan to utilize more than six classes, please include additional colors in this list.
        self.colors = [
            (0, 0, 255), 
            (0, 255, 0), 
            (255, 0, 0), 
            (255, 255, 0), 
            (255, 0, 255), 
            (0, 255, 255),
            (23, 39, 24),
            (12, 8, 50)
        ]
        

    def proccess_image(self, img):

        blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
        self.net.setInput(blob)
        outputs = self.net.forward(self.ln)
        outputs = np.vstack(outputs)
        
        coordinates = self.get_coordinates(outputs, 0.5)

        self.draw_identified_objects(img, coordinates)

        return coordinates

    def get_coordinates(self, outputs, conf):

        boxes = []
        confidences = []
        classIDs = []

        for output in outputs:
            scores = output[5:]
            
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > conf:
                x, y, w, h = output[:4] * np.array([self.W, self.H, self.W, self.H])
                p0 = int(x - w//2), int(y - h//2)
                boxes.append([*p0, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

        indices = cv.dnn.NMSBoxes(boxes, confidences, conf, conf-0.1)

        if len(indices) == 0:
            return []

        coordinates = []
        for i in indices.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            coordinates.append({'x': x, 'y': y, 'w': w, 'h': h, 'class': classIDs[i], 'class_name': self.classes[classIDs[i]]})
        return coordinates

    def draw_identified_objects(self, img, coordinates):
        for coordinate in coordinates:
            x = coordinate['x']
            y = coordinate['y']
            w = coordinate['w']
            h = coordinate['h']
            classID = coordinate['class']
            
            color = self.colors[classID]
            
            cv.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv.putText(img, self.classes[classID], (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv.imshow('window',  img)

# %%
# Run this cell to initiate detections using the trained model and record the annotated window to a video file.

window_name = "MAME: 三国战纪 - 风云再起 (版本 101, CN) [kovsh101]"
cfg_file_name = "./yolov4-tiny/yolov4-tiny-custom.cfg"
weights_file_name = "./yolov4-tiny/training/yolov4-tiny-custom_last.weights"

wincap = WindowCapture(window_name)
# get width,height as integers for VideoWriter
width, height = wincap.get_window_size()
improc = ImageProcessor((width, height), cfg_file_name, weights_file_name)

# --- Video recording setup ---
# Output path (will create folder if missing)
output_path = './recordings/detection_output.avi'
import os
os.makedirs(os.path.dirname(output_path), exist_ok=True)
# FourCC codec (mp4v works for .mp4 on many systems). Change to 'XVID' for .avi if preferred.
fourcc = cv.VideoWriter_fourcc(*'XVID')
fps = 20.0
frame_size = (int(width), int(height))
writer = cv.VideoWriter(output_path, fourcc, fps, frame_size)

# Ensure OpenCV window exists and prepare a WindowCapture for the display window.
cv.namedWindow('window', cv.WINDOW_NORMAL)
cv_wincap = None

while(True):
    # capture screenshot (BGR ndarray)
    ss = wincap.get_screenshot()
    
    # press 'q' to quit; release writer and close windows
    if cv.waitKey(1) == ord('q'):
        writer.release()
        cv.destroyAllWindows()
        break

    # process image (this function draws rectangles/text on the same img array)
    coordinates = improc.proccess_image(ss)
    
    # Attempt to capture the actual OpenCV display window and record that.
    # If we can't find or capture the display window, fall back to writing the annotated screenshot.
    frame_written = False
    try:
        if cv_wincap is None:
            try:
                cv_wincap = WindowCapture('window')
            except Exception:
                cv_wincap = None

        if cv_wincap is not None:
            win_frame = cv_wincap.get_screenshot()
            # resize if necessary
            if (win_frame.shape[1], win_frame.shape[0]) != frame_size:
                win_frame = cv.resize(win_frame, frame_size)
            writer.write(win_frame)
            frame_written = True
    except Exception as e:
        print('Warning: could not capture/write OpenCV display window:', e)

    if not frame_written:
        try:
            # fallback to the annotated screenshot (ss)
            if (ss.shape[1], ss.shape[0]) != frame_size:
                frame_to_write = cv.resize(ss, frame_size)
            else:
                frame_to_write = ss
            writer.write(frame_to_write)
        except Exception as e:
            print('Warning: could not write fallback frame to video file:', e)

    for coordinate in coordinates:
        print(coordinate)
    print()
    
    # If you have limited computer resources, consider adding a sleep delay between detections.
    # sleep(0.2)

# ensure writer released if loop exits normally
if writer.isOpened():
    writer.release()
print('Finished. Recorded to', output_path)
# Out:
# C:\Users\zengj\AppData\Local\Temp\ipykernel_54708\2781964491.py:32: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img = np.fromstring(signedIntsArray, dtype='uint8')
# {'x': 306, 'y': 272, 'w': 111, 'h': 170, 'class': np.int64(1), 'class_name': 'enemy'}
#
#
#
#
#
# {'x': 306, 'y': 272, 'w': 111, 'h': 170, 'class': np.int64(1), 'class_name': 'enemy'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'x': 524, 'y': 257, 'w': 440, 'h': 334, 'class': np.int64(3), 'class_name': 'player'}
#
#
#
#
#
# {'x': 524, 'y': 257, 'w': 440, 'h': 334, 'class': np.int64(3), 'class_name': 'player'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'x': 532, 'y': 247, 'w': 433, 'h': 359, 'class': np.int64(3), 'class_name': 'player'}
#
#
#
#
# {'x': 532, 'y': 247, 'w': 433, 'h': 359, 'class': np.int64(3), 'class_name': 'player'}
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {'x': 614, 'y': 149, 'w': 101, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
#
# {'x': 614, 'y': 149, 'w': 101, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 610, 'y': 150, 'w': 106, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 107, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 153, 'w': 106, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 844, 'y': 601, 'w': 110, 'h': 133, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 607, 'y': 153, 'w': 107, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 610, 'y': 150, 'w': 106, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 107, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 153, 'w': 106, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 844, 'y': 601, 'w': 110, 'h': 133, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 607, 'y': 153, 'w': 107, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 108, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 108, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 152, 'w': 108, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 107, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 108, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 108, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 152, 'w': 108, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 152, 'w': 107, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 104, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 154, 'w': 105, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 676, 'y': 586, 'w': 102, 'h': 142, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 607, 'y': 153, 'w': 97, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 103, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 104, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 607, 'y': 154, 'w': 105, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 676, 'y': 586, 'w': 102, 'h': 142, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 607, 'y': 153, 'w': 97, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 103, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 687, 'y': 513, 'w': 74, 'h': 151, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 608, 'y': 153, 'w': 103, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 152, 'w': 103, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 152, 'w': 102, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 687, 'y': 513, 'w': 74, 'h': 151, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 608, 'y': 153, 'w': 103, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 152, 'w': 103, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 152, 'w': 102, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 151, 'w': 92, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 496, 'y': 606, 'w': 83, 'h': 121, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 603, 'y': 151, 'w': 114, 'h': 67, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 604, 'y': 148, 'w': 111, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 150, 'w': 107, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 151, 'w': 92, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 496, 'y': 606, 'w': 83, 'h': 121, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 603, 'y': 151, 'w': 114, 'h': 67, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 604, 'y': 148, 'w': 111, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 150, 'w': 107, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 605, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 150, 'w': 106, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 644, 'y': 561, 'w': 93, 'h': 150, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 837, 'y': 601, 'w': 107, 'h': 120, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 613, 'y': 153, 'w': 96, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 485, 'y': 621, 'w': 85, 'h': 107, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 612, 'y': 154, 'w': 100, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 0, 'y': 109, 'w': 66, 'h': 260, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 740, 'y': 326, 'w': 92, 'h': 182, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 605, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 150, 'w': 106, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 644, 'y': 561, 'w': 93, 'h': 150, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 837, 'y': 601, 'w': 107, 'h': 120, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 613, 'y': 153, 'w': 96, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 485, 'y': 621, 'w': 85, 'h': 107, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 612, 'y': 154, 'w': 100, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 0, 'y': 109, 'w': 66, 'h': 260, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 740, 'y': 326, 'w': 92, 'h': 182, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 611, 'y': 154, 'w': 105, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 1, 'y': 94, 'w': 74, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 607, 'y': 154, 'w': 109, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 1, 'y': 81, 'w': 80, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 613, 'y': 158, 'w': 97, 'h': 47, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 153, 'w': 104, 'h': 50, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -3, 'y': 96, 'w': 113, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 611, 'y': 154, 'w': 105, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 1, 'y': 94, 'w': 74, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 607, 'y': 154, 'w': 109, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 1, 'y': 81, 'w': 80, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 613, 'y': 158, 'w': 97, 'h': 47, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 153, 'w': 104, 'h': 50, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -3, 'y': 96, 'w': 113, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 615, 'y': 149, 'w': 88, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -4, 'y': 121, 'w': 118, 'h': 241, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 612, 'y': 152, 'w': 101, 'h': 49, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -2, 'y': 112, 'w': 121, 'h': 260, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 0, 'y': 110, 'w': 147, 'h': 285, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 621, 'y': 598, 'w': 111, 'h': 132, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 612, 'y': 153, 'w': 99, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 152, 'w': 95, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -3, 'y': 91, 'w': 173, 'h': 345, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 615, 'y': 149, 'w': 88, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -4, 'y': 121, 'w': 118, 'h': 241, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 612, 'y': 152, 'w': 101, 'h': 49, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -2, 'y': 112, 'w': 121, 'h': 260, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 0, 'y': 110, 'w': 147, 'h': 285, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 621, 'y': 598, 'w': 111, 'h': 132, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 612, 'y': 153, 'w': 99, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 152, 'w': 95, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': -3, 'y': 91, 'w': 173, 'h': 345, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 1, 'y': 90, 'w': 166, 'h': 356, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 151, 'w': 98, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': -1, 'y': 102, 'w': 183, 'h': 335, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 151, 'w': 100, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 150, 'w': 94, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 610, 'y': 150, 'w': 101, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 1, 'y': 90, 'w': 166, 'h': 356, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 151, 'w': 98, 'h': 51, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': -1, 'y': 102, 'w': 183, 'h': 335, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 151, 'w': 100, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 150, 'w': 94, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 610, 'y': 150, 'w': 101, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 6, 'y': 134, 'w': 248, 'h': 321, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': -3, 'y': 135, 'w': 254, 'h': 332, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': -1, 'y': 134, 'w': 255, 'h': 330, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 0, 'y': 127, 'w': 268, 'h': 338, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 6, 'y': 134, 'w': 248, 'h': 321, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': -3, 'y': 135, 'w': 254, 'h': 332, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': -1, 'y': 134, 'w': 255, 'h': 330, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 0, 'y': 127, 'w': 268, 'h': 338, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 15, 'y': 122, 'w': 247, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 6, 'y': 141, 'w': 295, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 10, 'y': 116, 'w': 270, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 13, 'y': 122, 'w': 272, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 151, 'w': 109, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 15, 'y': 122, 'w': 247, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 6, 'y': 141, 'w': 295, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 10, 'y': 116, 'w': 270, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 13, 'y': 122, 'w': 272, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 151, 'w': 109, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 24, 'y': 117, 'w': 275, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 824, 'y': 609, 'w': 100, 'h': 109, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 28, 'y': 113, 'w': 292, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 152, 'w': 106, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 49, 'y': 114, 'w': 271, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 152, 'w': 106, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 84, 'y': 108, 'w': 251, 'h': 322, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 24, 'y': 117, 'w': 275, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 824, 'y': 609, 'w': 100, 'h': 109, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 28, 'y': 113, 'w': 292, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 152, 'w': 106, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 49, 'y': 114, 'w': 271, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 152, 'w': 106, 'h': 52, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 84, 'y': 108, 'w': 251, 'h': 322, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 83, 'y': 112, 'w': 269, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 101, 'y': 113, 'w': 257, 'h': 315, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 825, 'y': 605, 'w': 96, 'h': 115, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 94, 'y': 119, 'w': 277, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 105, 'y': 112, 'w': 264, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 83, 'y': 112, 'w': 269, 'h': 319, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 101, 'y': 113, 'w': 257, 'h': 315, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 825, 'y': 605, 'w': 96, 'h': 115, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 94, 'y': 119, 'w': 277, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 105, 'y': 112, 'w': 264, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 114, 'y': 134, 'w': 262, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 112, 'y': 117, 'w': 284, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 131, 'y': 118, 'w': 258, 'h': 300, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 149, 'w': 103, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 124, 'y': 128, 'w': 279, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 114, 'y': 134, 'w': 262, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 112, 'y': 117, 'w': 284, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 131, 'y': 118, 'w': 258, 'h': 300, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 149, 'w': 103, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 124, 'y': 128, 'w': 279, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 139, 'y': 127, 'w': 280, 'h': 300, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 152, 'y': 125, 'w': 275, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 149, 'y': 118, 'w': 289, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 149, 'w': 104, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 164, 'y': 148, 'w': 323, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 139, 'y': 127, 'w': 280, 'h': 300, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 152, 'y': 125, 'w': 275, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 149, 'y': 118, 'w': 289, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 149, 'w': 104, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 164, 'y': 148, 'w': 323, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 178, 'y': 145, 'w': 298, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 206, 'y': 140, 'w': 257, 'h': 299, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 211, 'y': 126, 'w': 270, 'h': 333, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 149, 'w': 103, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 245, 'y': 118, 'w': 249, 'h': 295, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 104, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 178, 'y': 145, 'w': 298, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 206, 'y': 140, 'w': 257, 'h': 299, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 211, 'y': 126, 'w': 270, 'h': 333, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 149, 'w': 103, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 245, 'y': 118, 'w': 249, 'h': 295, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 104, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 243, 'y': 114, 'w': 270, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 148, 'w': 105, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 258, 'y': 108, 'w': 269, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 150, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 283, 'y': 100, 'w': 263, 'h': 341, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 151, 'w': 109, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 7, 'y': 28, 'w': 262, 'h': 206, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 291, 'y': 99, 'w': 269, 'h': 337, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 150, 'w': 107, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 5, 'y': 1, 'w': 289, 'h': 252, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 243, 'y': 114, 'w': 270, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 148, 'w': 105, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 258, 'y': 108, 'w': 269, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 150, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 283, 'y': 100, 'w': 263, 'h': 341, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 151, 'w': 109, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 7, 'y': 28, 'w': 262, 'h': 206, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 291, 'y': 99, 'w': 269, 'h': 337, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 150, 'w': 107, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 5, 'y': 1, 'w': 289, 'h': 252, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 313, 'y': 94, 'w': 265, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 148, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 324, 'y': 97, 'w': 267, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 148, 'w': 112, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 332, 'y': 98, 'w': 250, 'h': 329, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 146, 'w': 110, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 24, 'y': -4, 'w': 301, 'h': 264, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 336, 'y': 95, 'w': 257, 'h': 325, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 148, 'w': 102, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 22, 'y': 30, 'w': 292, 'h': 199, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 313, 'y': 94, 'w': 265, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 148, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 324, 'y': 97, 'w': 267, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 148, 'w': 112, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 332, 'y': 98, 'w': 250, 'h': 329, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 146, 'w': 110, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 24, 'y': -4, 'w': 301, 'h': 264, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 336, 'y': 95, 'w': 257, 'h': 325, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 148, 'w': 102, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 22, 'y': 30, 'w': 292, 'h': 199, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 336, 'y': 94, 'w': 282, 'h': 336, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 150, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 19, 'y': 37, 'w': 286, 'h': 202, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 584, 'w': 290, 'h': 145, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 731, 'y': 225, 'w': 451, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 341, 'y': 91, 'w': 279, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 102, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 355, 'y': 102, 'w': 273, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 145, 'w': 103, 'h': 64, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 343, 'y': 102, 'w': 308, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 145, 'w': 97, 'h': 66, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 336, 'y': 94, 'w': 282, 'h': 336, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 150, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 19, 'y': 37, 'w': 286, 'h': 202, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 584, 'w': 290, 'h': 145, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 731, 'y': 225, 'w': 451, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 341, 'y': 91, 'w': 279, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 148, 'w': 102, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 355, 'y': 102, 'w': 273, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 609, 'y': 145, 'w': 103, 'h': 64, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 343, 'y': 102, 'w': 308, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 145, 'w': 97, 'h': 66, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 371, 'y': 95, 'w': 283, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 145, 'w': 92, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 31, 'y': 30, 'w': 234, 'h': 207, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 375, 'y': 98, 'w': 282, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 28, 'y': 27, 'w': 238, 'h': 201, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 611, 'y': 142, 'w': 100, 'h': 70, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 394, 'y': 92, 'w': 273, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 145, 'w': 95, 'h': 67, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 410, 'y': 108, 'w': 286, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 144, 'w': 105, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 371, 'y': 95, 'w': 283, 'h': 326, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 145, 'w': 92, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 31, 'y': 30, 'w': 234, 'h': 207, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 375, 'y': 98, 'w': 282, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 28, 'y': 27, 'w': 238, 'h': 201, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 611, 'y': 142, 'w': 100, 'h': 70, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 394, 'y': 92, 'w': 273, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 145, 'w': 95, 'h': 67, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 410, 'y': 108, 'w': 286, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 608, 'y': 144, 'w': 105, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 426, 'y': 92, 'w': 263, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 612, 'y': 148, 'w': 100, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 424, 'y': 88, 'w': 281, 'h': 323, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 146, 'w': 94, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 45, 'y': 24, 'w': 250, 'h': 204, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 577, 'y': 589, 'w': 348, 'h': 143, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 432, 'y': 86, 'w': 280, 'h': 331, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 53, 'y': 27, 'w': 245, 'h': 199, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 616, 'y': 145, 'w': 88, 'h': 71, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 431, 'y': 89, 'w': 297, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 145, 'w': 100, 'h': 66, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 426, 'y': 92, 'w': 263, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 612, 'y': 148, 'w': 100, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 424, 'y': 88, 'w': 281, 'h': 323, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 614, 'y': 146, 'w': 94, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 45, 'y': 24, 'w': 250, 'h': 204, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 577, 'y': 589, 'w': 348, 'h': 143, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 432, 'y': 86, 'w': 280, 'h': 331, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 53, 'y': 27, 'w': 245, 'h': 199, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 616, 'y': 145, 'w': 88, 'h': 71, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 431, 'y': 89, 'w': 297, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 145, 'w': 100, 'h': 66, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 437, 'y': 103, 'w': 295, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 148, 'w': 97, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 448, 'y': 106, 'w': 288, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 150, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 466, 'y': 99, 'w': 296, 'h': 330, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 146, 'w': 108, 'h': 75, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 476, 'y': 116, 'w': 303, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 150, 'w': 113, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 437, 'y': 103, 'w': 295, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 148, 'w': 97, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 448, 'y': 106, 'w': 288, 'h': 318, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 150, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 466, 'y': 99, 'w': 296, 'h': 330, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 146, 'w': 108, 'h': 75, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 476, 'y': 116, 'w': 303, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 150, 'w': 113, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 506, 'y': 113, 'w': 272, 'h': 294, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 150, 'w': 121, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 518, 'y': 118, 'w': 266, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 153, 'w': 113, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 510, 'y': 113, 'w': 298, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 515, 'y': 118, 'w': 308, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 506, 'y': 113, 'w': 272, 'h': 294, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 150, 'w': 121, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 518, 'y': 118, 'w': 266, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 606, 'y': 153, 'w': 113, 'h': 68, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 510, 'y': 113, 'w': 298, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 515, 'y': 118, 'w': 308, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 531, 'y': 112, 'w': 276, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 540, 'y': 111, 'w': 287, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 546, 'y': 122, 'w': 301, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 151, 'w': 88, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 548, 'y': 119, 'w': 293, 'h': 353, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 531, 'y': 112, 'w': 276, 'h': 302, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 540, 'y': 111, 'w': 287, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 546, 'y': 122, 'w': 301, 'h': 298, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 611, 'y': 151, 'w': 88, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 548, 'y': 119, 'w': 293, 'h': 353, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 537, 'y': 128, 'w': 302, 'h': 337, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 133, 'w': 307, 'h': 329, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 538, 'y': 131, 'w': 308, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 130, 'w': 319, 'h': 328, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 594, 'y': 147, 'w': 118, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 537, 'y': 128, 'w': 302, 'h': 337, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 133, 'w': 307, 'h': 329, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 538, 'y': 131, 'w': 308, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 130, 'w': 319, 'h': 328, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 594, 'y': 147, 'w': 118, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 529, 'y': 126, 'w': 319, 'h': 350, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 597, 'y': 146, 'w': 113, 'h': 64, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 539, 'y': 129, 'w': 301, 'h': 339, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 553, 'y': 130, 'w': 281, 'h': 295, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 558, 'y': 131, 'w': 275, 'h': 291, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 529, 'y': 126, 'w': 319, 'h': 350, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 597, 'y': 146, 'w': 113, 'h': 64, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 539, 'y': 129, 'w': 301, 'h': 339, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 553, 'y': 130, 'w': 281, 'h': 295, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 558, 'y': 131, 'w': 275, 'h': 291, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 568, 'y': 123, 'w': 249, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 570, 'y': 133, 'w': 244, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 570, 'y': 119, 'w': 249, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 560, 'y': 116, 'w': 277, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 568, 'y': 123, 'w': 249, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 570, 'y': 133, 'w': 244, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 570, 'y': 119, 'w': 249, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 560, 'y': 116, 'w': 277, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 559, 'y': 100, 'w': 280, 'h': 345, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 602, 'y': 116, 'w': 231, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 569, 'y': 122, 'w': 266, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 569, 'y': 124, 'w': 255, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 135, 'w': 104, 'h': 88, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 559, 'y': 100, 'w': 280, 'h': 345, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 602, 'y': 116, 'w': 231, 'h': 316, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 569, 'y': 122, 'w': 266, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 569, 'y': 124, 'w': 255, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 135, 'w': 104, 'h': 88, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 570, 'y': 125, 'w': 262, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 147, 'w': 92, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 562, 'y': 128, 'w': 279, 'h': 299, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 147, 'w': 89, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 558, 'y': 123, 'w': 269, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 124, 'w': 391, 'h': 368, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 570, 'y': 125, 'w': 262, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 607, 'y': 147, 'w': 92, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 562, 'y': 128, 'w': 279, 'h': 299, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 147, 'w': 89, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 558, 'y': 123, 'w': 269, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 532, 'y': 124, 'w': 391, 'h': 368, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 534, 'y': 137, 'w': 328, 'h': 325, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 150, 'w': 101, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 571, 'y': 127, 'w': 312, 'h': 335, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 150, 'w': 98, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 149, 'w': 93, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 580, 'y': 131, 'w': 306, 'h': 284, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 583, 'y': 139, 'w': 354, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 151, 'w': 95, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 534, 'y': 137, 'w': 328, 'h': 325, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 150, 'w': 101, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 571, 'y': 127, 'w': 312, 'h': 335, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 604, 'y': 150, 'w': 98, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 149, 'w': 93, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 580, 'y': 131, 'w': 306, 'h': 284, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 583, 'y': 139, 'w': 354, 'h': 314, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 151, 'w': 95, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 152, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 589, 'y': 141, 'w': 344, 'h': 315, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 603, 'y': 136, 'w': 353, 'h': 324, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 151, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 152, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 622, 'y': 127, 'w': 315, 'h': 296, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 639, 'y': 122, 'w': 304, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 618, 'y': 152, 'w': 91, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 152, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 589, 'y': 141, 'w': 344, 'h': 315, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 603, 'y': 136, 'w': 353, 'h': 324, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 151, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 606, 'y': 152, 'w': 97, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 622, 'y': 127, 'w': 315, 'h': 296, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 639, 'y': 122, 'w': 304, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 618, 'y': 152, 'w': 91, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 671, 'y': 112, 'w': 296, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 152, 'w': 87, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 673, 'y': 104, 'w': 307, 'h': 343, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 617, 'y': 152, 'w': 92, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 663, 'y': 100, 'w': 258, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 150, 'w': 87, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 696, 'y': 105, 'w': 262, 'h': 320, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 612, 'y': 152, 'w': 100, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 671, 'y': 112, 'w': 296, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 152, 'w': 87, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 673, 'y': 104, 'w': 307, 'h': 343, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 617, 'y': 152, 'w': 92, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 663, 'y': 100, 'w': 258, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 619, 'y': 150, 'w': 87, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 696, 'y': 105, 'w': 262, 'h': 320, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 612, 'y': 152, 'w': 100, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 664, 'y': 103, 'w': 259, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 149, 'w': 86, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 684, 'y': 98, 'w': 298, 'h': 317, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 149, 'w': 102, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 674, 'y': 104, 'w': 295, 'h': 322, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 150, 'w': 89, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 690, 'y': 94, 'w': 272, 'h': 334, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 148, 'w': 101, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 664, 'y': 103, 'w': 259, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 613, 'y': 149, 'w': 86, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 684, 'y': 98, 'w': 298, 'h': 317, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 149, 'w': 102, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 674, 'y': 104, 'w': 295, 'h': 322, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 610, 'y': 150, 'w': 89, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 690, 'y': 94, 'w': 272, 'h': 334, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 603, 'y': 148, 'w': 101, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 694, 'y': 78, 'w': 298, 'h': 342, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 597, 'y': 148, 'w': 106, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 681, 'y': 104, 'w': 332, 'h': 336, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 148, 'w': 100, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 715, 'y': 22, 'w': 311, 'h': 464, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 615, 'y': 149, 'w': 91, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 604, 'y': 147, 'w': 97, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 728, 'y': 9, 'w': 240, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 694, 'y': 78, 'w': 298, 'h': 342, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 597, 'y': 148, 'w': 106, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 681, 'y': 104, 'w': 332, 'h': 336, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 148, 'w': 100, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 715, 'y': 22, 'w': 311, 'h': 464, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 615, 'y': 149, 'w': 91, 'h': 63, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 604, 'y': 147, 'w': 97, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 728, 'y': 9, 'w': 240, 'h': 289, 'class': np.int64(3), 'class_name': 'player'}
#
# {'x': 603, 'y': 149, 'w': 101, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 719, 'y': 18, 'w': 258, 'h': 287, 'class': np.int64(3), 'class_name': 'player'}
#
#
# {'x': 603, 'y': 151, 'w': 100, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 149, 'w': 101, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 719, 'y': 18, 'w': 258, 'h': 287, 'class': np.int64(3), 'class_name': 'player'}
#
#
# {'x': 603, 'y': 151, 'w': 100, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 151, 'w': 100, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 151, 'w': 99, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 150, 'w': 101, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 601, 'y': 149, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 151, 'w': 100, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 151, 'w': 99, 'h': 62, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 603, 'y': 150, 'w': 101, 'h': 61, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 601, 'y': 149, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 602, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
# {'x': 608, 'y': 149, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 602, 'y': 148, 'w': 103, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
# {'x': 608, 'y': 149, 'w': 105, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 152, 'w': 104, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 154, 'w': 110, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 108, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 134, 'w': 118, 'h': 89, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 609, 'y': 152, 'w': 104, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 154, 'w': 110, 'h': 53, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 608, 'y': 153, 'w': 108, 'h': 54, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 615, 'y': 134, 'w': 118, 'h': 89, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 589, 'y': 142, 'w': 122, 'h': 97, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 611, 'y': 154, 'w': 98, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
# {'x': 589, 'y': 142, 'w': 122, 'h': 97, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 611, 'y': 154, 'w': 98, 'h': 60, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
#
#
# {'x': 590, 'y': 139, 'w': 121, 'h': 96, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
# {'x': 590, 'y': 139, 'w': 121, 'h': 96, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
# {'x': 611, 'y': 153, 'w': 104, 'h': 55, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
#
#
#
# {'x': 612, 'y': 139, 'w': 109, 'h': 91, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
#
#
# {'x': 612, 'y': 139, 'w': 109, 'h': 91, 'class': np.int64(5), 'class_name': 'time_label'}
#
#
# {'x': 933, 'y': 230, 'w': 304, 'h': 279, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 943, 'y': 530, 'w': 283, 'h': 205, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 612, 'y': 142, 'w': 113, 'h': 87, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 697, 'y': 421, 'w': 161, 'h': 253, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 961, 'y': 264, 'w': 260, 'h': 227, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 946, 'y': 538, 'w': 272, 'h': 195, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 701, 'y': 424, 'w': 155, 'h': 249, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 969, 'y': 261, 'w': 256, 'h': 231, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 956, 'y': 532, 'w': 256, 'h': 205, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 671, 'y': 167, 'w': 184, 'h': 206, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 609, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 663, 'y': 301, 'w': 187, 'h': 167, 'class': np.int64(1), 'class_name': 'enemy'}
#
#
# {'x': 933, 'y': 230, 'w': 304, 'h': 279, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 943, 'y': 530, 'w': 283, 'h': 205, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 612, 'y': 142, 'w': 113, 'h': 87, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 697, 'y': 421, 'w': 161, 'h': 253, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 961, 'y': 264, 'w': 260, 'h': 227, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 946, 'y': 538, 'w': 272, 'h': 195, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 701, 'y': 424, 'w': 155, 'h': 249, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 969, 'y': 261, 'w': 256, 'h': 231, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 956, 'y': 532, 'w': 256, 'h': 205, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 671, 'y': 167, 'w': 184, 'h': 206, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 609, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
# {'x': 663, 'y': 301, 'w': 187, 'h': 167, 'class': np.int64(1), 'class_name': 'enemy'}
#
# {'x': 692, 'y': 422, 'w': 164, 'h': 252, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 957, 'y': 259, 'w': 269, 'h': 229, 'class': np.int64(1), 'class_name': 'enemy'}
# {'x': 956, 'y': 525, 'w': 260, 'h': 214, 'class': np.int64(1), 'class_name': 'enemy'}
# ...
#
# {'x': 677, 'y': 311, 'w': 276, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 652, 'y': 311, 'w': 296, 'h': 291, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 598, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 654, 'y': 309, 'w': 297, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 598, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 654, 'y': 308, 'w': 290, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 680, 'y': 315, 'w': 276, 'h': 287, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 109, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 677, 'y': 311, 'w': 276, 'h': 290, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 652, 'y': 311, 'w': 296, 'h': 291, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 598, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 654, 'y': 309, 'w': 297, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 598, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 654, 'y': 308, 'w': 290, 'h': 297, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 650, 'y': 314, 'w': 295, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 674, 'y': 316, 'w': 285, 'h': 268, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 683, 'y': 313, 'w': 271, 'h': 273, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 683, 'y': 313, 'w': 271, 'h': 273, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 284, 'w': 282, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 602, 'y': 153, 'w': 105, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 650, 'y': 314, 'w': 295, 'h': 288, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 674, 'y': 316, 'w': 285, 'h': 268, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 683, 'y': 313, 'w': 271, 'h': 273, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 683, 'y': 313, 'w': 271, 'h': 273, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 605, 'y': 152, 'w': 101, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 284, 'w': 282, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 602, 'y': 153, 'w': 105, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 282, 'w': 275, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 282, 'w': 275, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 283, 'w': 273, 'h': 305, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 280, 'w': 270, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 280, 'w': 270, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 282, 'w': 275, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 282, 'w': 275, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 706, 'y': 283, 'w': 273, 'h': 305, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 280, 'w': 270, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 280, 'w': 270, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 281, 'w': 272, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 276, 'w': 283, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 276, 'w': 283, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 283, 'w': 267, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 154, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 282, 'w': 266, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 154, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 281, 'w': 272, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 276, 'w': 283, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 276, 'w': 283, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 283, 'w': 267, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 154, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 282, 'w': 266, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 154, 'w': 109, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 698, 'y': 287, 'w': 264, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 698, 'y': 287, 'w': 264, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 692, 'y': 291, 'w': 265, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 292, 'w': 258, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 292, 'w': 258, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 293, 'w': 260, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 106, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 698, 'y': 287, 'w': 264, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 698, 'y': 287, 'w': 264, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 154, 'w': 107, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 692, 'y': 291, 'w': 265, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 292, 'w': 258, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 292, 'w': 258, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 107, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 695, 'y': 293, 'w': 260, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 106, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 693, 'y': 294, 'w': 268, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 106, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 697, 'y': 294, 'w': 256, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 699, 'y': 296, 'w': 254, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 701, 'y': 294, 'w': 244, 'h': 309, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 701, 'y': 294, 'w': 245, 'h': 309, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 693, 'y': 294, 'w': 268, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 601, 'y': 153, 'w': 106, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 697, 'y': 294, 'w': 256, 'h': 304, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 699, 'y': 296, 'w': 254, 'h': 301, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 58, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 701, 'y': 294, 'w': 244, 'h': 309, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 701, 'y': 294, 'w': 245, 'h': 309, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 303, 'w': 232, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 700, 'y': 293, 'w': 244, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 700, 'y': 293, 'w': 244, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 711, 'y': 304, 'w': 218, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 713, 'y': 304, 'w': 222, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 303, 'w': 232, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 700, 'y': 293, 'w': 244, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 59, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 700, 'y': 293, 'w': 244, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 711, 'y': 304, 'w': 218, 'h': 311, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 713, 'y': 304, 'w': 222, 'h': 312, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 600, 'y': 153, 'w': 108, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 304, 'w': 234, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 304, 'w': 234, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 712, 'y': 305, 'w': 225, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 307, 'w': 228, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 707, 'y': 312, 'w': 239, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 113, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 304, 'w': 234, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 304, 'w': 234, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 110, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 712, 'y': 305, 'w': 225, 'h': 313, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 709, 'y': 307, 'w': 228, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 111, 'h': 57, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 707, 'y': 312, 'w': 239, 'h': 303, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 113, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 311, 'w': 241, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 113, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 309, 'w': 234, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 311, 'w': 237, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 703, 'y': 311, 'w': 234, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# Finished. Recorded to ./recordings/detection_output.avi
# {'x': 704, 'y': 311, 'w': 241, 'h': 306, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 113, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 705, 'y': 309, 'w': 234, 'h': 310, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 704, 'y': 311, 'w': 237, 'h': 307, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# {'x': 703, 'y': 311, 'w': 234, 'h': 308, 'class': np.int64(3), 'class_name': 'player'}
# {'x': 599, 'y': 153, 'w': 112, 'h': 56, 'class': np.int64(5), 'class_name': 'time_label'}
#
# Finished. Recorded to ./recordings/detection_output.avi
